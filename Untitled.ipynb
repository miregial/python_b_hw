# %%
#факториал с помощью цикла
from sympy import *
init_printing()
def factorial(n):
    f=1
    for k in range(2,n+1): #начали диапозон с 2х , потому что умножение на 1 ничего не меняет
        f=f*k #можно еще написать как f*=k
    return f
factorial(100)
# Out:
# 933262154439441526816992388562667004907159682643816214685929638952175999932299
# 156089414639761565182862536979208272237582511852109168640000000000000000000000
# 00

# %%
#СКОЛЬКО ЦИФР В ЧИСЛЕ
#1. превратил в строку (стр ту инт)
n = factorial(1000) #для факториала 1000
s = str(n)
type(s)
len(s)  #2. длина строки и есть количество цифр
# Out:
# 2568

# %%
#итерационные версии числа Фибонначе a,b = 1,1 
def fib(n):
    a,b = 1,1
    for k in range(n): #старое число будет становиться как б , но  последующее после б это а+б (1,1,2,3,5,8)
        a,b = b, a+b
    return a
fib(4)
# Out:
# 5

# %%
#ТЕПЕРЬ НЕ ОТ 0 А ОТ 1 БУДЕТ ТЕПЕРЬ итерационные версии числа Фибонначе a,b = 1,1  ЭТО 25 ЗАДАЧА ИЗ ПРОЕКТА ЭЙЛЕРА
def fib(n):
    a,b = 1,1
    for k in range(1,n): #старое число будет становиться как б , но  последующее после б это а+б (1,1,2,3,5,8)
        a,b = b, a+b
    return a
def len_fib(size):
    k=1
    len_fib = len(str(fib(k)))
    while len_fib<size:
        k+=1
        len_fib  = len(str(fib(k)))
    return (k, fib(k))
len_fib(3)
# Out:
# (12, 144)

# %%
#решить дома 34 задачу из проекта эйлера  miregial 02022000erary

# %%
def len_fib(size):
    k=1
    len_fib = len(str(fib(k)))
    while len_fib<size:
        k+=1
        len_fib  = len(str(fib(k)))
    return (k, fib(k))
len_fib(1000)
# Out:
# (4782, 10700662663827589367649805844573968850836838966321516650132352033753145
# 206046940406218891475824897926578046948881775919574843364666725699595129960304
# 612627480924821861440694330512347744427502737817530875793916661921492591867595
# 539664228371489431130746995034395470019854326097230672901928705264472437261177
# 158218255484911205250132014786129659313817922355596574520395061375514678375432
# 291196021299340482607061753977068470682028954869026661854351245219003694806413
# 574474709117076197669456910700980243934396174741037369125032313655321647736970
# 231677550515951735184605799549194109677783732296657965816465139034881542563101
# 842241902598460880001101862555502454939371136516570394476295847145485234259504
# 285824253060835444354282126110089928637950480068943303097732178348645431132057
# 656598684562886168087186938352973506439862976406600007235629179052070511640776
# 148124918858309459405666883391093509444565763576661516193177537928916615813271
# 59616877487983821820492520348473874384736771934512787029218636250627816)
